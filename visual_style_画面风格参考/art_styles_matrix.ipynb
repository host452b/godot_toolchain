# %% [markdown]
# # 2D 游戏画风 · 颜色矩阵
#
# 20 种 Steam 常见 2D 画风的对比矩阵。数据来自 `art_styles.csv`。
#
# **色阶**:`Steam欢迎度 / 商业安全性 / 独立适配度` 越高越绿;`制作难度` 反向——越低越绿(对小团队越友好)。评分为基于原始分析(制作难度 / 商业安全性 / Steam Top8 排名)派生的主观量化(0–100)。详尽分析、Prompt 模板与开发建议见 `README.md`。

# %%
# Out:
# <h3>全 20 种画风对比矩阵(按表序)</h3>
# <table style="border-collapse:collapse;font-size:11px;font-family:system-ui,Arial,sans-serif">
# ...

# %%
# Out:
# <h3>★ Steam 欢迎度 Top 8</h3>
# <table style="border-collapse:collapse;font-size:12px;font-family:system-ui,Arial,sans-serif">
# <tr><th style="background-color:#222;color:#fff;padding:4px 8px;white-space:nowrap;text-align:left">#</th><th style="background-color:#222;color:#fff;padding:4px 8px;white-space:nowrap;text-align:left">中文画风</th><th style="background-color:#222;color:#fff;padding:4px 8px;white-space:nowrap;text-align:left">代表作</th><th style="background-color:#222;color:#fff;padding:4px 8px;white-space:nowrap;text-align:left">Steam欢迎度</th><th style="background-color:#222;color:#fff;padding:4px 8px;white-space:nowrap;text-align:left">商业安全性</th><th style="background-color:#222;color:#fff;padding:4px 8px;white-space:nowrap;text-align:left">独立适配度</th></tr>
# ...

# %%
# Out:
# <h3>🛠 独立团队适配度 Top 8</h3>
# <table style="border-collapse:collapse;font-size:12px;font-family:system-ui,Arial,sans-serif">
# <tr><th style="background-color:#222;color:#fff;padding:4px 8px;white-space:nowrap;text-align:left">#</th><th style="background-color:#222;color:#fff;padding:4px 8px;white-space:nowrap;text-align:left">中文画风</th><th style="background-color:#222;color:#fff;padding:4px 8px;white-space:nowrap;text-align:left">代表作</th><th style="background-color:#222;color:#fff;padding:4px 8px;white-space:nowrap;text-align:left">Steam欢迎度</th><th style="background-color:#222;color:#fff;padding:4px 8px;white-space:nowrap;text-align:left">商业安全性</th><th style="background-color:#222;color:#fff;padding:4px 8px;white-space:nowrap;text-align:left">独立适配度</th></tr>
# ...
